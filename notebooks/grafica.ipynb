# %%
import matplotlib.pyplot as plt

# Datos
tiempo = [0, 10, 20, 30, 40, 50]
posicion = [30, 52, 38, 0, -37, -53]

# Crear el gráfico
plt.plot(tiempo, posicion, marker='o', linestyle='-')
plt.plot(tiempo, velocidad, marker='o', linestyle='-', color='pink')
plt.xlabel('Tiempo')
plt.ylabel('Velocida')
plt.title('Gráfico de posicion en función del Tiempo')
plt.grid(True)
plt.show()
